# %% [markdown]
# # Indeterminate Beam calculator
#
# ### Table of Contents
# 1. Initialisation
# 2. Basic Usage (Readme example)
#     - 2.1 Basic Usage
#     - 2.2 Querying Data
#     - 2.3 Specifiying Units
# 3. Support Class Breakdown
# 4. Load Classes Breakdown
#     - 4.1 Point Torque
#     - 4.2 Point Load
#     - 4.3 Uniformly Distributed Load (UDL)
#     - 4.4 Trapezoidal Load
#     - 4.5 Distributed Load
#     - 4.6 Vertical and Horizontal Load Child Classes
# 5. Statically Determinate Beam (Ex 12.14 Hibbeler)
# 6. Statically Indeterminate Beam (Ex 12.21 Hibbeler)
# 7. Spring Supported Beam (Ex 12.16 Hibbeler)
# 8. Axially Loaded Indeterminate Beam (Ex 4.13 Hibbeler)
#
# Note:
# You must always run the initialization cell first.
# Then you are free to move to any of the other sections as per the table of contents.

# %% [markdown]
#  ## 1. Initialisation

# %%
# RUN THIS CELL FIRST TO INITIALISE GOOGLE NOTEBOOK!!!!
# !pip install indeterminatebeam
# %matplotlib inline

# import beam and supports
from indeterminatebeam import Beam, Support

# import loads (all load types imported for reference)
from indeterminatebeam import (
    PointTorque,
    PointLoad,
    PointLoadV,
    PointLoadH,
    UDL,
    UDLV,
    UDLH,
    TrapezoidalLoad,
    TrapezoidalLoadV,
    TrapezoidalLoadH,
    DistributedLoad,
    DistributedLoadV,
    DistributedLoadH
)

# Note: load ending in V are vertical loads
# load ending in H are horizontal loads
# load not ending in either takes angle as an input (except torque)
# Out:
# Collecting indeterminatebeam
#   Downloading indeterminatebeam-2.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from indeterminatebeam) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from indeterminatebeam) (2.0.2)
# Requirement already satisfied: sympy>=1.10 in /usr/local/lib/python3.12/dist-packages (from indeterminatebeam) (1.13.3)
# Requirement already satisfied: plotly>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from indeterminatebeam) (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.14.1->indeterminatebeam) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=4.14.1->indeterminatebeam) (25.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.10->indeterminatebeam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->indeterminatebeam) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->indeterminatebeam) (1.17.0)
# Downloading indeterminatebeam-2.4.0-py3-none-any.whl (34 kB)
# Installing collected packages: indeterminatebeam
# Successfully installed indeterminatebeam-2.4.0

# %% [markdown]
# ## 2. Basic Usage (Readme example)

# %% [markdown]
# ### 2.1 Basic Usage

# %%
# Arbritrary example defined in README.md
beam = Beam(7)                          # Initialize a Beam object of length 7 m with E and I as defaults
beam_2 = Beam(9,E=2000, I =100000)      # Initialize a Beam specifying some beam parameters

a = Support(5,(1,1,0))                  # Defines a pin support at location x = 5 m
b = Support(0,(0,1,0))                  # Defines a roller support at location x = 0 m
c = Support(7,(1,1,1))                  # Defines a fixed support at location x = 7 m
beam.add_supports(a,b,c)

load_1 = PointLoadV(1000,2)                # Defines a point load of 1000 N acting up, at location x = 2 m
load_2 = DistributedLoadV(2000,(1,4))      # Defines a 2000 N/m UDL from location x = 1 m to x = 4 m
load_3 = PointTorque(2*10**3, 3.5)            # Defines a 2*10**3 N.m point torque at location x = 3.5 m
beam.add_loads(load_1,load_2,load_3)    # Assign the support objects to a beam object created earlier

# solve the beam
beam.analyse()

## plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# print results as a table with 10 points
beam.print_results_table(num_points=10, max_dp=3)

# optionally export as a csv
beam.export_results_csv(filename="beam_results.csv", num_points=10, max_dp=3)

# save the figures (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="78edcf8f-fcf4-4e98-a314-699a312de324" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78edcf8f-fcf4-4e98-a314-699a312de324")) {                    Plotly.newPlot(                        "78edcf8f-fcf4-4e98-a314-699a312de324",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,7],"y":[0,0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[0, 1, 0]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[0],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","hoverinfo":"skip","marker":{"color":"blue","size":10,"symbol":"arrow-up"},"mode":"markers","name":"Support","showlegend":false,"x":[0],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 0]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[5],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"toself","hoverinfo":"skip","marker":{"color":"blue","size":10,"symbol":"arrow-up"},"mode":"markers","name":"Support","showlegend":false,"x":[5],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[7],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eForce: %{meta[0]:.3f} %{meta[3]}            \u003cbr\u003eAngle: %{meta[5]:.3f} deg","marker":{"color":"red","size":10,"symbol":"triangle-up"},"meta":[1000,2,"m","N","N.m",90],"mode":"markers","name":"Point\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[2],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"mediumpurple","width":1},"mode":"lines","name":"Distributed\u003cbr\u003eLoad","x":[1.0,1.01,1.02,1.03,1.04,1.05,1.06,1.07,1.08,1.09,1.1,1.11,1.12,1.13,1.1400000000000001,1.15,1.16,1.17,1.18,1.19,1.2,1.21,1.22,1.23,1.24,1.25,1.26,1.27,1.28,1.29,1.3,1.31,1.32,1.33,1.34,1.35,1.3599999999999999,1.37,1.38,1.3900000000000001,1.4,1.4100000000000001,1.42,1.43,1.44,1.45,1.46,1.47,1.48,1.49,1.5,1.51,1.52,1.53,1.54,1.55,1.56,1.57,1.58,1.5899999999999999,1.6,1.6099999999999999,1.62,1.63,1.6400000000000001,1.65,1.6600000000000001,1.67,1.6800000000000002,1.69,1.7000000000000002,1.71,1.72,1.73,1.74,1.75,1.76,1.77,1.78,1.79,1.8,1.81,1.82,1.83,1.8399999999999999,1.85,1.8599999999999999,1.87,1.88,1.8900000000000001,1.9,1.9100000000000001,1.92,1.9300000000000002,1.94,1.9500000000000002,1.96,1.97,1.98,1.99,2.0,2.01,2.02,2.0300000000000002,2.04,2.05,2.06,2.0700000000000003,2.08,2.09,2.1,2.1100000000000003,2.12,2.13,2.14,2.1500000000000004,2.16,2.17,2.1799999999999997,2.19,2.2,2.21,2.2199999999999998,2.23,2.24,2.25,2.26,2.27,2.2800000000000002,2.29,2.3,2.31,2.3200000000000003,2.33,2.34,2.35,2.3600000000000003,2.37,2.38,2.39,2.4000000000000004,2.41,2.42,2.4299999999999997,2.44,2.45,2.46,2.4699999999999998,2.48,2.49,2.5,2.51,2.52,2.5300000000000002,2.54,2.55,2.56,2.5700000000000003,2.58,2.59,2.6,2.6100000000000003,2.62,2.63,2.64,2.6500000000000004,2.66,2.67,2.6799999999999997,2.69,2.7,2.71,2.7199999999999998,2.73,2.74,2.75,2.76,2.77,2.7800000000000002,2.79,2.8,2.81,2.8 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
,4.78391959798995,4.819095477386934,4.8542713567839195,4.889447236180905,4.924623115577889,4.959798994974874,4.994974874371859,4.9999999,5.0000001,5.030150753768845,5.065326633165829,5.100502512562814,5.135678391959799,5.1708542713567835,5.206030150753769,5.241206030150754,5.276381909547738,5.311557788944723,5.346733668341709,5.381909547738694,5.417085427135678,5.452261306532663,5.4874371859296485,5.522613065326633,5.557788944723618,5.592964824120603,5.628140703517587,5.663316582914573,5.698492462311558,5.733668341708543,5.768844221105527,5.8040201005025125,5.839195979899498,5.874371859296482,5.909547738693467,5.944723618090452,5.9798994 ...
#  x [m]  Axial [N]  Shear [N]  Moment [N.m]  Deflection [m]
#  0.000          0  -2381.538         0.000           0.000
#  0.778          0  -2381.538     -1852.308           0.002
#  1.556          0  -1270.427     -3395.973           0.004
#  2.333          0   1285.128     -3445.812           0.004
#  3.111          0   2840.684     -1841.330           0.003
#  3.889          0   4396.239     -1026.971           0.002
#  4.667          0   4618.462      2552.821           0.000
#  5.444          0  -3069.231      2728.205          -0.000
#  6.222          0  -3069.231       341.026          -0.000
#  7.000          0      0.000         0.000           0.000
# Results exported to beam_results.csv

# %%
# Arbritrary example defined in README.md
beam = Beam(7)                          # Initialize a Beam object of length 7 m with E and I as defaults
beam_2 = Beam(9,E=2000, I =100000)      # Initialize a Beam specifying some beam parameters

b = Support(0,(1,1,1))                  # Defines a roller support at location x = 0 m
c = Support(7,(1,1,1))                  # Defines a fixed support at location x = 7 m
beam.add_supports(b,c)

load_2 = DistributedLoadV(2000,(1,4))      # Defines a 2000 N/m UDL from location x = 1 m to x = 4 m
beam.add_loads(load_2)    # Assign the support objects to a beam object created earlier


beam.analyse()

## plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2972a754-c2f3-4ff4-b40b-e2b977feed7f" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2972a754-c2f3-4ff4-b40b-e2b977feed7f")) {                    Plotly.newPlot(                        "2972a754-c2f3-4ff4-b40b-e2b977feed7f",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,7],"y":[0,0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[0],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[7],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"mediumpurple","width":1},"mode":"lines","name":"Distributed\u003cbr\u003eLoad","x":[1.0,1.01,1.02,1.03,1.04,1.05,1.06,1.07,1.08,1.09,1.1,1.11,1.12,1.13,1.1400000000000001,1.15,1.16,1.17,1.18,1.19,1.2,1.21,1.22,1.23,1.24,1.25,1.26,1.27,1.28,1.29,1.3,1.31,1.32,1.33,1.34,1.35,1.3599999999999999,1.37,1.38,1.3900000000000001,1.4,1.4100000000000001,1.42,1.43,1.44,1.45,1.46,1.47,1.48,1.49,1.5,1.51,1.52,1.53,1.54,1.55,1.56,1.57,1.58,1.5899999999999999,1.6,1.6099999999999999,1.62,1.63,1.6400000000000001,1.65,1.6600000000000001,1.67,1.6800000000000002,1.69,1.7000000000000002,1.71,1.72,1.73,1.74,1.75,1.76,1.77,1.78,1.79,1.8,1.81,1.82,1.83,1
##add a query point to a plot (adds values on plot)
beam.add_query_points(1,3,5)
beam.remove_query_points(5)

## plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")
# Out:
# bending moments at 3 m: -2913.9941862974
# shear forces at 1,2,3,4,5m points: [-4172.0116618076, -2172.0118618076, -172.0118618076, 1827.9883381924, 1827.9883381924]
# normal force absolute max: 0.0
# deflection max: 0.0043381774
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a91c22b7-5fd9-4c7e-aab8-397e0bee9d8f" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a91c22b7-5fd9-4c7e-aab8-397e0bee9d8f")) {                    Plotly.newPlot(                        "a91c22b7-5fd9-4c7e-aab8-397e0bee9d8f",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,7],"y":[0,0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[0],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[7],"y":[0],"type":"scatter","xaxis":"x","yaxis":"y"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"mediumpurple","width":1},"mode":"lines","name":"Distributed\u003cbr\u003eLoad","x":[1.0,1.01,1.02,1.03,1.04,1.05,1.06,1.07,1.08,1.09,1.1,1.11,1.12,1.13,1.1400000000000001,1.15,1.16,1.17,1.18,1.19,1.2,1.21,1.22,1.23,1.24,1.25,1.26,1.27,1.28,1.29,1.3,1.31,1.32,1.33,1.34,1.35,1.3599999999999999,1.37,1.38,1.3900000000000001,1.4,1.4100000000000001,1.42,1.43,1.44,1.45,1.46,1.47,1.48,1.49,1.5,1.51,1.52,1.53,1.54,1.55,1.56,1.57,1.58,1.5899999999999999,1.6,1.6099999999999999,1.62,1.63,1.6400000000000001,1.65,1.6600000000000001,1.67,1.6800000000000002,1.69,1.7000000000000002,1.71,1.72,1.73,1.74,1.75,1.76,1.77,1.78,1.79,1.8,1.81,1.82,1.83,1.8399999999999999,1.85,1.8599999999999999,1.87,1.88,1.8900000000000001,1.9,1.9100000000000001,1.92,1.9300000000000002,1.94,1.9500000000000002,1.96,1.97,1.98,1.99,2.0,2.01,2.02,2.0300000000000002,2.04,2.05,2.06,2.0700000000000003,2.08,2.09,2.1,2.1100000000000003,2.12,2.13,2.14,2.1500000000000004,2.16,2.17,2.1799999999999997,2.19,2.2,2.21,2.2199999999999998,2.23,2.24,2.25,2.26,2.27,2.2800000000000002,2.29,2.3,2.31,2.3200000000000003,2.33,2.34,2.35,2.3600000000000003,2.37,2.38,2.39,2.4000000000000004,2.41,2.42,2.4299999999999997,2.44,2.45,2.46,2.4699999999999998,2.48,2.49,2.5,2.51,2.52,2.5300000000000002,2.54,2.55,2.56,2.5700000000000003,2.58,2.59,2.6,2.6100000000000003,2.62,2.63,2.64,2.6500000000000004,2.66,2.67,2.6799999999999997,2.69,2.7,2.71,2.7199999999999998,2.73,2.74,2.75,2.76,2.77,2.7800000000000002,2.79,2.8,2.81,2.8200000000000003,2.83,2.84,2.85,2.8600000000000003,2.87,2.88,2.89,2.9000000000000004,2.91,2.92,2.9299999999999997,2.94,2.95,2.96,2.9699999999999998,2.98,2.99,3.0,3.0100000000000002,3.02,3.0300000000000002,3.04,3.05,3.06,3.07,3.08,3.09,3.1,3.11,3.12,3.13,3.14,3.15,3.16,3.17,3.18,3.19,3.2,3.21,3.22,3.23,3.24,3.25,3
728643216080402,3.7638190954773867,3.798994974874372,3.8341708542713566,3.869346733668342,3.9045226130653266,3.9396984924623117,3.9748743718592965,3.9999999,4.0000001,4.010050251256281,4.045226130653266,4.080402010050252,4.115577889447236,4.150753768844221,4.185929648241206,4.221105527638191,4.256281407035176,4.291457286432161,4.326633165829145,4.36180904522613,4.396984924623116,4.432160804020101,4.467336683417085,4.50251256281407,4.5376884422110555,4.57286432160804,4.608040201005025,4.64321608040201,4.678391959798995,4.71356783919598,4.748743718592965,4.78391959798995,4.819095477386934,4.8542713567839195,4.889447236180905,4.924623115577889,4.959798994974874,4.994974874371859,5.030150753768845,5.065326633165829,5.100502512562814,5.135678391959799,5.1708542713567835,5.206030150753769,5.241206030150754,5.276381909547738,5.311557788944723,5.346733668341709,5.381909547738694,5.417085427135678,5.452261306532663,5.4874371859296485,5.522613065326633,5.557788944723618,5.592964824120603,5.628140703517587,5.663316582914573,5.698492462311558,5.733668341708543,5.768844221105527,5.8040201005025125,5.839195979899498,5.874371859296482,5.909547738693467,5.944723618090452,5.9798994974874375,6.015075376884422,6.050251256281407,6.085427135678 ...

# %% [markdown]
# ## 2.3 Specifying Units

# %%
# Readme example as a demonstration for changing units
# used and presented in following example. Note that
# the example is conceptually identical only with
# different units.

# update units usings the update_units() function.
# use the command below for more information.
# help(beam.update_units)

# note: initialising beam with the anticipation that units will be updated
beam = Beam(7000, E = 200 * 10 **6, I = 9.05 * 10 **6)

beam.update_units(key='length', unit='mm')
beam.update_units('force', 'kN')
beam.update_units('distributed', 'kN/m')
beam.update_units('moment', 'kN.m')
beam.update_units('E', 'kPa')
beam.update_units('I', 'mm4')
beam.update_units('deflection', 'mm')

a = Support(5000,(1,1,0))               # Defines a pin support at location x = 5 m (x = 5000 mm)
b = Support(0,(0,1,0))                  # Defines a roller support at location x = 0 m
c = Support(7000,(1,1,1))               # Defines a fixed support at location x = 7 m (x = 7000 mm)
beam.add_supports(a,b,c)

load_1 = PointLoadV(1,2000)             # Defines a point load of 1000 N (1 kN) acting up, at location x = 2 m
load_2 = DistributedLoadV(2,(1000,4000))      # Defines a 2000 N/m (2 kN/m) UDL from location x = 1 m to x = 4 m
load_3 = PointTorque(2, 3500)           # Defines a 2*10**3 N.m (2 kN.m) point torque at location x = 3.5 m
beam.add_loads(load_1,load_2,load_3)    # Assign the support objects to a beam object created earlier

beam.analyse()

## plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="67a69538-c953-424d-91d1-805115302c41" class="plotly-graph-div" style="height:550px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67a69538-c953-424d-91d1-805115302c41")) {                    Plotly.newPlot(                        "67a69538-c953-424d-91d1-805115302c41",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["mm"],"mode":"lines","name":"Beam_","x":[0,7000],"y":[0,0],"type":"scatter","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["
# 2333.333           0       1.285         -3.446            4.096
# 3111.111           0       2.841         -1.841            3.415
# 3888.889           0       4.396         -1.027            2.068
# 4666.667           0       4.618          2.553            0.487
# 5444.444           0      -3.069          2.728           -0.304
# 6222.222           0      -3.069          0.341           -0.209
# 7000.000           0       0.000          0.000            0.000

# %% [markdown]
# ## 3. Support class breakdown

# %%
# The parameters for a support class are as below, taken from the docstring
# for the Support class __init__ method.

# Parameters:
#         -----------
#         coord: float
#             x coordinate of support on a beam in m (default 0)
#         fixed: tuple of 3 booleans
#             Degrees of freedom that are fixed on a beam for movement in
#             x, y and bending, 1 represents fixed and 0 represents free
#             (default (1,1,1))
#         kx :
#             stiffness of x support (N/m), if set will overide the
#             value placed in the fixed tuple. (default = None)
#         ky : (positive number)
#             stiffness of y support (N/m), if set will overide the
#             value placed in the fixed tuple. (default = None)


# Lets define every possible degree of freedom combination for
# supports below, and view them on a plot:
support_0 = Support(0, (1,1,1))     # conventional fixed support
support_1 = Support(1, (1,1,0))     # conventional pin support
support_2 = Support(2, (1,0,1))
support_3 = Support(3, (0,1,1))
support_4 = Support(4, (0,0,1))
support_5 = Support(5, (0,1,0))     # conventional roller support
support_6 = Support(6, (1,0,0))

# Note we could also explicitly define parameters as follows:
support_0 = Support(coord=0, fixed=(1,1,1))

# Now lets define some spring supports
support_7 = Support(7, (0,0,0), kx = 10)    #spring in x direction only
support_8 = Support(8, (0,0,0), ky = 5)     # spring in y direction only
support_9 = Support(9, (0,0,0), kx = 100, ky = 100)     # spring in x and y direction

# Now lets define a support which is fixed in one degree of freedom
# but has a spring stiffness in another degree of freedom
support_10 = Support(10, (0,1,0), kx = 10) #spring in x direction, fixed in y direction
support_11 = Support(11, (0,1,1), kx = 10) #spring in x direction, fixed in y and m direction

# Note we could also do the following for the same result since the spring
# stiffness overides the fixed boolean in respective directions
support_10 = Support(10, (1,1,0), kx =10)

# Now lets plot all the supports we have created
beam = Beam(11)

beam.add_supports(
    support_0,
    support_1,
    support_2,
    support_3,
    support_4,
    support_5,
    support_6,
    support_7,
    support_8,
    support_9,
    support_10,
    support_11,
)

## plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8fe0e064-4ae9-40c3-a538-f9c4b850b2c4" class="plotly-graph-div" style="height:350px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fe0e064-4ae9-40c3-a538-f9c4b850b2c4")) {                    Plotly.newPlot(                        "8fe0e064-4ae9-40c3-a538-f9c4b850b2c4",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,11],"y":[0,0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[0],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 1, 0]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[1],"y":[0],"type":"scatter"},{"fill":"toself","hoverinfo":"skip","marker":{"color":"blue","size":10,"symbol":"arrow-up"},"mode":"markers","name":"Support","showlegend":false,"x":[1],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 0, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[2],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[0, 1, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[3],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[0, 0, 1]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[4],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[0, 1, 0]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[5],"y":[0],"type":"scatter"},{"fill":"toself","hoverinfo":"skip","marker":{"color":"blue","size":10,"symbol":"arrow-up"},"mode":"markers","name":"Support","showlegend":false,"x":[5],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[1]}\u003cbr\u003eFixed: %{meta[0]}","marker":{"color":"blue","size":10,"symbol":"triangle-up"},"meta":["[1, 0, 0]","m"],"mode":"markers","name":"Support","opacity":0,"showlegend":false,"x":[6],"y":[0],"type":"scatter"},{"fill":"toself","hoverinfo":"skip","marker":{"color":"blue","size":10,"symbol":"arrow-right"},"mode":"markers","name":"Support","showlegend":false,"x":[6],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[2]}\u003cbr\u003ekx: %{meta[0]:.3f} %{meta[3]}","marker":{"color":"orange","size":10,"symbol":"triangle-up"},"meta":[10,0,"m","N\u002fm"],"mode":"markers","name":"Spring","opacity":0,"showlegend":false,"x":[7],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[2]}\u003cbr\u003eky: %{meta[1]:.3f} %{meta[3]}","marker":{"color":"orange","size":10,"symbol":"triangle-up"},"meta":[0,5,"m","N\u002fm"],"mode":"markers","name":"Spring","opacity":0,"showlegend":false,"x":[8],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{x:.3f} %{meta[2]}\u003cbr\u003ekx: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eky: %{meta[1]:.3f} %{meta[3]}","marker":{"color":"orange","size":10,"symbol":"triangle-up"},"meta":[ ...

# %% [markdown]
# ## 4. Load classes breakdown

# %% [markdown]
# ### 4.1 Point Torque

# %%
# defined using a force (technically a moment, however force is used to maintain consistenct for all load classes) and a coordinate. An anti-clockwise moment is positive by convention of this package.
load_1 = PointTorque(force=1000, coord=1)
load_2 = PointTorque(force=-1000, coord=2)

# Plotting the loads
beam = Beam(3)
beam.add_loads(
    load_1,
    load_2
)


## plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3bd4d9c5-6c4f-477b-a39e-ead544bc46aa" class="plotly-graph-div" style="height:350px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3bd4d9c5-6c4f-477b-a39e-ead544bc46aa")) {                    Plotly.newPlot(                        "3bd4d9c5-6c4f-477b-a39e-ead544bc46aa",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,3],"y":[0,0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eMoment: %{meta[0]:.3f} %{meta[4]}","marker":{"color":"magenta","size":10,"symbol":"triangle-up"},"meta":[1000,1,"m","N","N.m"],"mode":"markers","name":"Point\u003cbr\u003eTorque","opacity":0,"showlegend":false,"x":[1],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eMoment: %{meta[0]:.3f} %{meta[4]}","marker":{"color":"magenta","size":10,"symbol":"triangle-up"},"meta":[-1000,2,"m","N","N.m"],"mode":"markers","name":"Point\u003cbr\u003eTorque","opacity":0,"showlegend":false,"x":[2],"y":[0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords" ...

# %% [markdown]
# ### 4.2 Point Load

# %%
# defined by force, coord and angle (0)
load_1 = PointLoad(force=1000, coord=1, angle=0)
load_2 = PointLoad(force=1000, coord=2, angle=45)
load_3 = PointLoad(force=1000, coord=3, angle=90)

# Plotting the loads
beam = Beam(4)
beam.add_loads(
    load_1,
    load_2,
    load_3
)

## plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c78daaa8-a546-4de4-87fe-1f2a2a590c1b" class="plotly-graph-div" style="height:350px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c78daaa8-a546-4de4-87fe-1f2a2a590c1b")) {                    Plotly.newPlot(                        "c78daaa8-a546-4de4-87fe-1f2a2a590c1b",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,4],"y":[0,0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eForce: %{meta[0]:.3f} %{meta[3]}            \u003cbr\u003eAngle: %{meta[5]:.3f} deg","marker":{"color":"red","size":10,"symbol":"triangle-up"},"meta":[1000,1,"m","N","N.m",0],"mode":"markers","name":"Point\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[1],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eForce: %{meta[0]:.3f} %{meta[3]}            \u003cbr\u003eAngle: %{meta[5]:.3f} deg","marker":{"color":"red","size":10,"symbol":"triangle-up"},"meta":[1000,2,"m","N","N.m",45],"mode":"markers","name":"Point\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[2],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[1]:.3f} %{meta[2]}\u003cbr\u003eForce: %{meta[0]:.3f} %{meta[3]}            \u003cbr\u003eAngle: %{meta[5]:.3f} deg","marker":{"color":"red","size":10,"symbol":"triangle-up"},"meta":[1000,3,"m","N","N.m",90],"mode":"markers","name":"Point\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[3],"y":[0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorsca ...

# %% [markdown]
# ### 4.3 Uniformly Distributed Load (UDL)

# %%
# defined by force, span (tuple with start and end point)
# and angle of force
load_1 = UDL(force=1000, span=(1,2), angle = 0)
load_2 = UDL(force=1000, span=(3,4), angle = 45)
load_3 = UDL(force=1000, span=(5,6), angle = 90)

# Plotting the loads
beam = Beam(7)
beam.add_loads(
    load_1,
    load_2,
    load_3
)

## plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8a8b569-6128-4c78-b455-ea733e734551" class="plotly-graph-div" style="height:350px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8a8b569-6128-4c78-b455-ea733e734551")) {                    Plotly.newPlot(                        "b8a8b569-6128-4c78-b455-ea733e734551",                        [{"hoverinfo":"skip","hovertemplate":"%{x} %{meta[0]}","line":{"color":"purple","width":2},"meta":["m"],"mode":"lines","name":"Beam_","x":[0,7],"y":[0,0],"type":"scatter"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"maroon","width":1},"mode":"lines","name":"UDL","x":[1,2],"y":[-1.0,-1.0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"maroon","size":10,"symbol":"triangle-up"},"meta":[1,1000,0,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[1],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"maroon","size":10,"symbol":"triangle-up"},"meta":[2,1000,0,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[2],"y":[0],"type":"scatter"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"green","width":1},"mode":"lines","name":"UDL","x":[3,4],"y":[-1.0,-1.0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"green","size":10,"symbol":"triangle-up"},"meta":[3,1000,45,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[3],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"green","size":10,"symbol":"triangle-up"},"meta":[4,1000,45,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[4],"y":[0],"type":"scatter"},{"fill":"tozeroy","hoverinfo":"skip","hovertemplate":"","line":{"color":"mediumpurple","width":1},"mode":"lines","name":"UDL","x":[5,6],"y":[-1.0,-1.0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"mediumpurple","size":10,"symbol":"triangle-up"},"meta":[5,1000,90,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[5],"y":[0],"type":"scatter"},{"hoverinfo":"skip","hovertemplate":"x: %{meta[0]:.3f} %{meta[3]}\u003cbr\u003eForce: %{meta[1]:.3f} %{meta[4]}        \u003cbr\u003eAngle: %{meta[2]:.3f} deg","marker":{"color":"mediumpurple","size":10,"symbol":"triangle-up"},"meta":[6,1000,90,"m","N\u002fm"],"mode":"markers","name":"Distributed\u003cbr\u003eLoad","opacity":0,"showlegend":false,"x":[6],"y":[0],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"tick ...

# %% [markdown]
# ### 4.4 Trapezoidal Load

# %%
# defined by force (tuple with start and end force),
# span (tuple with start and end point) and angle of force
load_1 = TrapezoidalLoad(force=(1000,2000), span=(1,2), angle = 0)
load_2 = TrapezoidalLoad(force=(-1000,-2000), span=(3,4), angle = 45)
load_3 = TrapezoidalLoad(force=(-1000,2000), span=(5,6), angle = 90)

# Plotting the loads
beam = Beam(7)
beam.add_loads(
    load_1,
    load_2,
    load_3
)

# plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()

# %% [markdown]
# ### 4.5 Distributed Load

# %%
# defined with Sympy expression of the distributed load function
# expressed using variable x which represents the beam x-coordinate.
# Requires quotation marks around expression. As with the UDL and
# Trapezoidal load classes other parameters to express are the span
# (tuple with start and end point) and angle of force.
# NOTE: where UDL or Trapezoidal load classes can be spefied (linear functions)
# they should be used for quicker analysis times.

load_1 = DistributedLoad(expr= "2", span=(1,2), angle = 0)
load_2 = DistributedLoad(expr= "2*(x-6)**2 -5", span=(3,4), angle = 45)
load_3 = DistributedLoad(expr= "cos(5*x)", span=(5,6), angle = 90)

# Plotting the loads
beam = Beam(7)
beam.add_loads(
    load_1,
    load_2,
    load_3
)

# plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()

# %% [markdown]
# ### 4.6 Vertical and Horizontal Load Child Classes

# %%
# for all loads except the point torque an angle is specified for the
# direction of the load. If the load to be specified is to be completely
# vertical or completely horizontal a V (vertical) or a H (horizontal)
# can be added at the end of the class name, and the angle does then
# not need to be spefied.

# The following two loads are equivalent horizontal loads
load_1 = PointLoad(force=1000, coord=1, angle = 0)
load_2 = PointLoadH(force=1000, coord=2)

# The following two loads are equivalent vertical loads
load_3 = PointLoad(force=1000, coord=3, angle = 90)
load_4 = PointLoadV(force=1000, coord=4)

# The following two loads are also equivalent (a negative sign
# esentially changes the load direction by 180 degrees).
load_5 = PointLoad(force=1000, coord=5, angle = 0)
load_6 = PointLoad(force=-1000, coord=6, angle = 180)


# Plotting the loads
beam = Beam(7)
beam.add_loads(
    load_1,
    load_2,
    load_3,
    load_4,
    load_5,
    load_6
)

# plot the results for the beam
fig_1 = beam.plot_beam_diagram()
fig_1.show()

# %% [markdown]
# ## 5. Statically Determinate Beam (Ex 12.14 Hibbeler)

# %%
# Statically Determinate beam (Ex 12.14 Hibbeler)
# Determine the displacement at x = 8m for the following structure
# 8 m long fixed at A (x = 0m)
# A trapezoidal load of - 4000 N/m at x = 0 m descending to 0 N/m at x = 6 m.

beam = Beam(8, E=1, I = 1)     ##EI Defined to be 1 get the deflection as a function of EI

a = Support(0, (1,1,1))             ##explicitly stated although this is equivalent to Support() as the defaults are for a cantilever on the left of the beam.

load_1 = TrapezoidalLoadV((-4000,0),(0,6))

beam.add_supports(a)
beam.add_loads(load_1)

beam.analyse()

print(f"Deflection is {beam.get_deflection(8)} N.m3 / EI (N.m2)")

# plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")

# %% [markdown]
# ## 6. Statically Indeterminate Beam (Ex 12.21 Hibbeler)

# %%
# Statically Indeterminate beam (Ex 12.21 Hibbeler)
# Determine the reactions at the roller support B of the beam described below:
# 3 m long, fixed at A (x = 0 m), roller support at B (x=3 m),
# vertical point load at midpan of 8000 N, UDL of 6000 N/m, EI constant.

beam = Beam(3)

a = Support(0,(1,1,1))
b = Support(3,(0,1,0))

load_1 = PointLoadV(-8000,1.5)
load_2 = UDLV(-6000, (0,3))

beam.add_supports(a,b)
beam.add_loads(load_1,load_2)

beam.analyse()

print(f"The beam has an absolute maximum shear force of: {beam.get_shear_force(return_absmax=True)} N")
print(f"The beam has an absolute maximum bending moment of: {beam.get_bending_moment(return_absmax=True)} N.mm")
print(f"The beam has a vertical reaction at B of: {beam.get_reaction(3,'y')} N")

# plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")

# %% [markdown]
# ## 7. Spring Supported Beam (Ex 12.16 Hibbeler)

# %%
# Spring Supported beam (Ex 12.16 Hibbeler)
# Determine the vertical displacement at x = 1 m for the beam detailed below:
# 3 m long, spring of ky = 45 kN/m at A (x = 0 m) and B (x = 3 m), vertical point load at x = 1 m of 3000 N, E = 200 GPa, I = 4.6875*10**-6 m4.

# when initializing beam we should specify E and I. Units should be expressed in MPa (N/mm2) for E, and mm4 for I
beam = Beam(3, E=(200)*10**3, I=(4.6875*10**-6)*10**12)

# creating supports, note that an x support must be specified even when there are no x forces. This will not affect the accuracy or reliability of results.
# Also note that ky units are kN/m in the problem but must be in N/m for the program to work correctly.
a = Support(0, (1,1,0), ky = 45000)
b = Support(3, (0,1,0), ky = 45000)

load_1 = PointLoadV(-3000, 1)

beam.add_supports(a,b)
beam.add_loads(load_1)

beam.analyse()

beam.get_deflection(1)

# plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")

##results in 38.46 mm deflection ~= 38.4mm specified in textbook (difference only due to their rounding)
##can easily check reliability of answer by looking at deflection at the spring supports. Should equal F/k.
## ie at support A (x = 0 m), the reaction force is 2kN by equilibrium, so our deflection is F/K = 2kn / 45*10-3 kN/mm = 44.4 mm (can be seen in plot)

# %% [markdown]
# ## 8. Axially Loaded Indeterminate Beam (Ex 4.13 Hibbeler)

# %%
##AXIAL LOADED INDETERMINATE BEAM (Ex 4.13 Hibbeler)
## A rod with constant EA has a force of 60kN applied at x = 0.1 m, and the beam has fixed supports at x=0, and x =0.4 m. Determine the reaction forces.

beam = Beam(0.4)

a = Support()
b = Support(0.4)

load_1 = PointLoadH(-60000, 0.1)

beam.add_supports(a,b)
beam.add_loads(load_1)

beam.analyse()

# plot the results for the beam
fig_1 = beam.plot_beam_external()
fig_1.show()

fig_2 = beam.plot_beam_internal()
fig_2.show()

# save the results (optional)
# Can save figure using ``fig.write_image("./results.pdf")`` (can change extension to be
# png, jpg, svg or other formats as reired). Requires pip install -U kaleido

# fig_1.write_image("./example_plot_external.png")
# fig_2.write_image("./example_plot_internal.png")
